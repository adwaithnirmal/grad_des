# %% [markdown]
# # EE 508 HW 1 Part 1: Gradient Descent
#
# Your task in this Colab notebook is to fill out the sections that are specified by **TODO** (please search the keyword `TODO` to make sure you do not miss any).

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use(['ggplot'])

# %% [markdown]
# ## Gradient Descent for Linear Regression
#
# Given two vectors, X and Y, that represent the input and output values of a linear relationship, we can fit a line to this data to predict the output for other values of X. This can be done by finding the parameters $w$ and $b$ of the line, such that the line minimizes the squared error between the predicted and actual output values.
#
# The equation for the line is:
#
# \begin{equation}
# \hat{y} = w \cdot x + b
# \end{equation}
#
# where:
#
# * $\hat{y}$ is the predicted output value.
# * $w$ is the slope
# * $b$ is the intercept
#
# Let's use Gradient Descent to find the best values for $\theta$ as defined below:
#
# \begin{equation}
# \theta = \begin{bmatrix} w \\ b\end{bmatrix} \end{equation}

# %% [markdown]
# ## Create Data
#
# Let's generate some data with:
#
# \begin{equation} \theta = \begin{bmatrix} 2 \\ 3 \end{bmatrix} \end{equation}
#
# We will use this data to fit the line and then use it to predict the output for other values of $x$.
# *   `number_of_samples` is an integer variable
# *   X is a vector of `number_of_samples` numbers between 1, 100
# *   Y is a vector of `number_of_samples` numbers where each $y = w \cdot x + b$ plus some noise, which is a random value between 0 and 1.

# %%
number_of_samples = 100

X = 2 * np.random.rand(number_of_samples, 1)
y = 2 * X + np.random.rand(number_of_samples, 1) + 3

theta_guess = np.array([[1.0], [1.0]])
learning_rate = 0.001
num_iterations = 500

final_cost = {}
final_theta = {}

# %% [markdown]
# Plot and visualize your data.

# %%
plt.plot(X,y,'b.')
plt.xlabel("$x$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
_ = plt.axis([0,np.max(X),0,np.max(y)])

# %% [markdown]
# ## Gradient Descent Implementation

# %% [markdown]
# The equation for calculating cost function and gradients are as shown below.
#
# Make prediction:
#
# \begin{equation}
# \hat{y} =w \cdot x + b
# \end{equation}
#
# Mean squared error:
#
# \begin{equation}
# J(w, b) = \text{MSE}(w, b) = \frac{1}{n} \sum_{i=1}^n (\hat{y}_i - y_i)^2 = \frac{1}{n} \sum_{i=1}^n (e_i)^2
# \end{equation}
#
# where residual error is
# \begin{equation}
# e_i=\hat{y}_i - y_i
# \end{equation}
#
# Gradient:
#
# \begin{equation}
# \nabla J(w, b) = \left( \frac{\partial J}{\partial w}, \frac{\partial J}{\partial b} \right)
# \end{equation}
#
# Apply chain rule:
#
# \begin{equation}
# \nabla J(w, b) = \left( \sum_{i=1}^n (\frac{\partial J}{\partial e_i} \cdot \frac{\partial e_i}{\partial w}), \sum_{i=1}^n(\frac{\partial J}{\partial e_i} \cdot \frac{\partial e_i}{\partial b}) \right)
#
# = \left( \frac{2}{n} \sum_{i=1}^n e_i \times {x}_i, \frac{2}{n} \sum_{i=1}^n e_i \times 1 \right)
# \end{equation}
#
# Replace $e_i$:
#
# \begin{equation}
# \nabla J(w, b) = \left( \frac{2}{n} \sum_{i=1}^n (\hat{y}_i - y_i) \times {x}_i, \frac{2}{n} \sum_{i=1}^n (\hat{y}_i - y_i) \times 1 \right)
# \end{equation}

# %% [markdown]
# ### **TODO 1:**
# If we define the residual error as $(y_i - \hat{y}_i)$, will the gradient equation $\nabla J(w, b)$ change? Show your derivation.

# %% [markdown]
# Your answer:

# %% [markdown]
# Your answer here.

# %% [markdown]
# ### **TODO 1 & 2:**
#
# Implement the following helper functions in the skeleton code below:
#
# 1.  `calculate_prediction_residuals(theta, X, y)`: Calculate the predictions ($X \cdot \theta$) and the residuals (predictions - y).
# 2.  `calculate_cost(theta, X, y)`: Calculate the Mean Squared Error (MSE) cost: $J(\theta) = \frac{1}{m} \sum (h_\theta(x^{(i)}) - y^{(i)})^2$.
# 3.  `calculate_gradient(X, residuals)`: Calculate the gradient of the cost function: $\nabla J(\theta) = \frac{2}{m} X^T \cdot (X \theta - y)$.
#
# Follow the comments in the skeleton cell.

# %%
# Skeleton for TODO 1 & 2
def calculate_prediction_residuals(theta, X, y):
    """
    Calculate the predictions and residuals.

    Parameters:
    - theta (numpy.ndarray): Parameter vector of shape (num_features,).
    - X (numpy.ndarray): Feature matrix of shape (num_samples, num_features).
    - y (numpy.ndarray): Target values of shape (num_samples,).

    Returns:
    - predictions (numpy.ndarray): X * theta
    - residuals (numpy.ndarray): predictions - y
    """
    # 1. Compute predictions
    # ... your code here ...
    predictions = np.dot(X , theta )

    # 2. Compute residuals
    # ... your code here ...
    residuals = predictions - y

    return predictions, residuals

def calculate_cost(theta, X, y):
    """
    Calculate the cost (Mean Squared Error) for linear regression.

    Parameters:
    - theta (numpy.ndarray): Parameter vector.
    - X (numpy.ndarray): Feature matrix.
    - y (numpy.ndarray): Target values.

    Returns:
    - cost (float): The MSE cost.
    """
    # 1. Get residuals using calculate_prediction_residuals
    # ... your code here ...
    _,residuals = calculate_prediction_residuals(theta, X, y)

    # 2. Compute cost = (1/num_samples) * sum(residuals^2)
    # ... your code here ...
    cost = np.mean(residuals**2)
    return cost

def calculate_gradient(X, residuals):
    """
    Calculate the gradient for linear regression.

    Parameters:
    - X (numpy.ndarray): Feature matrix.
    - residuals (numpy.ndarray): Residuals.

    Returns:
    - gradient (numpy.ndarray): Gradient vector.
    """
    # 1. Compute gradient = (2/num_samples) * (X.T dot residuals)
    # ... your code here ...
    num_samples = X.shape[0]
    gradient = 2/num_samples * np.dot(X.T , residuals)
    return gradient

# %% [markdown]
# ### **TODO 3:**
# In the next cell, write the Python code to implement Gradient Descent.
#
# 1.  Initialize `cost_history` list.
# 2.  Loop `num_iterations` times.
# 3.  Inside the loop:
#     *   Calculate predictions and residuals.
#     *   Calculate the gradient.
#     *   Update `theta` using the update rule: $\theta = \theta - \alpha \nabla J(\theta)$.
#     *   Calculate the new cost and append it to `cost_history`.
# 4.  Return optimized `theta` and `cost_history`.

# %%
# Skeleton for TODO 3
def gradient_descent(X, y, theta, learning_rate, num_iterations):
    """
    Perform gradient descent to optimize parameters for linear regression.

    Parameters:
    - X (numpy.ndarray): Feature matrix.
    - y (numpy.ndarray): Target values.
    - theta (numpy.ndarray): Initial parameter vector.
    - learning_rate (float): Learning rate.
    - num_iterations (int): Number of iterations.

    Returns:
    - theta (numpy.ndarray): Optimized parameter vector.
    - cost_history (list): List of cost values over iterations.
    """
    cost_history = []

    for _ in range(num_iterations):
        # 1. Calculate predictions and residuals
        # ... your code here ...
        _,residuals = calculate_prediction_residuals(theta, X, y)

        # 2. Calculate gradient
        # ... your code here ...
        gradient = calculate_gradient(X, residuals)

        # 3. Update theta
        # ... your code here ...
        theta = theta - learning_rate * gradient

        # 4. Calculate cost and append to history
        # ... your code here ...
        cost = calculate_cost(theta, X, y)
        cost_history.append(cost)
        pass

    return theta, cost_history

# %% [markdown]
# ## Gradient Descent Virtualization
#
# In the next cell, run the GD implementation, store the cost for each iteration and plot the cost vs. iterations.

# %%
# Skeleton for TODO 3 (continued)
theta = theta_guess.copy()

# 1. Add column of ones to X
X_b = np.c_[X, np.ones((len(X), 1))]

# 2. Run Gradient Descent
# theta, cost_history = ...
theta, cost_history = gradient_descent(X_b, y, theta, learning_rate, num_iterations)

# 3. Plot cost history
# ... your code here ...
plt.plot(range(num_iterations), cost_history)
plt.xlabel('Iteration')
plt.ylabel('Cost')
plt.title('Cost vs. Iterations ')
plt.show()
for i, cost in enumerate(cost_history):
    print(f"Iteration {i}: Cost = {cost:.4f}")
# Out:
# Iteration 0: Cost = 12.6424
# Iteration 1: Cost = 12.5295
# Iteration 2: Cost = 12.4177
# Iteration 3: Cost = 12.3069
# Iteration 4: Cost = 12.1971
# Iteration 5: Cost = 12.0883
# Iteration 6: Cost = 11.9805
# Iteration 7: Cost = 11.8737
# Iteration 8: Cost = 11.7679
# Iteration 9: Cost = 11.6630
# Iteration 10: Cost = 11.5591
# Iteration 11: Cost = 11.4562
# Iteration 12: Cost = 11.3542
# Iteration 13: Cost = 11.2531
# Iteration 14: Cost = 11.1530
# Iteration 15: Cost = 11.0538
# Iteration 16: Cost = 10.9555
# Iteration 17: Cost = 10.8581
# Iteration 18: Cost = 10.7615
# Iteration 19: Cost = 10.6659
# Iteration 20: Cost = 10.5712
# Iteration 21: Cost = 10.4773
# Iteration 22: Cost = 10.3843
# Iteration 23: Cost = 10.2921
# Iteration 24: Cost = 10.2008
# Iteration 25: Cost = 10.1103
# Iteration 26: Cost = 10.0206
# Iteration 27: Cost = 9.9318
# Iteration 28: Cost = 9.8438
# Iteration 29: Cost = 9.7566
# Iteration 30: Cost = 9.6702
# Iteration 31: Cost = 9.5846
# Iteration 32: Cost = 9.4997
# Iteration 33: Cost = 9.4157
# Iteration 34: Cost = 9.3324
# Iteration 35: Cost = 9.2499
# Iteration 36: Cost = 9.1681
# Iteration 37: Cost = 9.0871
# Iteration 38: Cost = 9.0068
# Iteration 39: Cost = 8.9273
# Iteration 40: Cost = 8.8485
# Iteration 41: Cost = 8.7704
# Iteration 42: Cost = 8.6930
# Iteration 43: Cost = 8.6164
# Iteration 44: Cost = 8.5404
# Iteration 45: Cost = 8.4651
# Iteration 46: Cost = 8.3906
# Iteration 47: Cost = 8.3167
# Iteration 48: Cost = 8.2435
# Iteration 49: Cost = 8.1709
# Iteration 50: Cost = 8.0991
# Iteration 51: Cost = 8.0279
# Iteration 52: Cost = 7.9573
# Iteration 53: Cost = 7.8874
# Iteration 54: Cost = 7.8181
# Iteration 55: Cost = 7.7495
# Iteration 56: Cost = 7.6815
# Iteration 57: Cost = 7.6141
# Iteration 58: Cost = 7.5473
# Iteration 59: Cost = 7.4811
# Iteration 60: Cost = 7.4156
# Iteration 61: Cost = 7.3506
# Iteration 62: Cost = 7.2863
# Iteration 63: Cost = 7.2225
# Iteration 64: Cost = 7.1593
# Iteration 65: Cost = 7.0967
# Iteration 66: Cost = 7.0347
# Iteration 67: Cost = 6.9733
# Iteration 68: Cost = 6.9124
# Iteration 69: Cost = 6.8520
# Iteration 70: Cost = 6.7922
# Iteration 71: Cost = 6.7330
# Iteration 72: Cost = 6.6743
# Iteration 73: Cost = 6.6161
# Iteration 74: Cost = 6.5585
# Iteration 75: Cost = 6.5014
# Iteration 76: Cost = 6.4448
# Iteration 77: Cost = 6.3888
# Iteration 78: Cost = 6.3332
# Iteration 79: Cost = 6.2782
# Iteration 80: Cost = 6.2237
# Iteration 81: Cost = 6.1697
# Iteration 82: Cost = 6.1161
# Iteration 83: Cost = 6.0631
# Iteration 84: Cost = 6.0105
# Iteration 85: Cost = 5.9584
# Iteration 86: Cost = 5.9068
# Iteration 87: Cost = 5.8557
# Iteration 88: Cost = 5.8051
# Iteration 89: Cost = 5.7549
# Iteration 90: Cost = 5.7051
# Iteration 91: Cost = 5.6558
# Iteration 92: Cost = 5.6070
# Iteration 93: Cost = 5.5586
# Iteration 94: Cost = 5.5107
# Iteration 95: Cost = 5.4632
# Iteration 96: Cost = 5.4161
# Iteration 97: Cost = 5.3695
# Iteration 98: Cost = 5.3233
# Iteration 99: Cost = 5.2775
# Iteration 100: Cost = 5.2321
# Iteration 101: Cost = 5.1872
# Iteration 102: Cost = 5.1426
# Iteration 103: Cost = 5.0985
# Iteration 104: Cost = 5.0548
# Iteration 105: Cost = 5.0115
# Iteration 106: Cost = 4.9685
# Iteration 107: Cost = 4.9260
# Iteration 108: Cost = 4.8838
# Iteration 109: Cost = 4.8421
# Iteration 110: Cost = 4.8007
# Iteration 111: Cost = 4.7597
# Iteration 112: Cost = 4.7191
# Iteration 113: Cost = 4.6788
# Iteration 114: Cost = 4.6389
# Iteration 115: Cost = 4.5994
# Iteration 116: Cost = 4.5603
# Iteration 117: Cost = 4.5215
# Iteration 118: Cost = 4.4830
# Iteration 119: Cost = 4.4449
# Iteration 120: Cost = 4.4072
# Iteration 121: Cost = 4.3698
# Iteration 122: Cost = 4.3327
# Iteration 123: Cost = 4.2960
# Iteration 124: Cost = 4.2596
# Iteration 125: Cost = 4.2236
# Iteration 126: Cost = 4.1878
# Iteration 127: Cost = 4.1525
# Iteration 128: Cost = 4.1174
# Iteration 129: Cost = 4.0826
# Iteration 130: Cost = 4.0482
# Iteration 131: Cost = 4.0141
# Iteration 132: Cost = 3.9803
# Iteration 133: Cost = 3.9468
# Iteration 134: Cost = 3.9136
# Iteration 135: Cost = 3.8807
# Iteration 136: Cost = 3.8481
# Iteration 137: Cost = 3.8158
# Iteration 138: Cost = 3.7839
# Iteration 139: Cost = 3.7522
# Iteration 140: Cost = 3.7207
# Iteration 141: Cost = 3.6896
# Iteration 142: Cost = 3.6588
# Iteration 143: Cost = 3.6282
# Iteration 144: Cost = 3.5979
# Iteration 145: Cost = 3.5679
# Iteration 146: Cost = 3.5382
# Iteration 147: Cost = 3.5088
# Iteration 148: Cost = 3.4796
# Iteration 149: Cost = 3.4507
# Iteration 150: Cost = 3.4220
# Iteration 151: Cost = 3.3936
# Iteration 152: Cost = 3.3655
# Iteration 153: Cost = 3.3376
# Iteration 154: Cost = 3.3100
# Iteration 155: Cost = 3.2826
# Iteration 156: Cost = 3.2555
# Iteration 157: Cost = 3.2286
# Iteration 158: Cost = 3.2020
# Iteration 159: Cost = 3.1756
# Iteration 160: Cost = 3.1495
# Iteration 161: Cost = 3.1236
# Iteration 162: Cost = 3.0979
# Iteration 163: Cost = 3.0725
# Iteration 164: Cost = 3.0473
# Iteration 165: Cost = 3.0223
# Iteration 166: Cost = 2.9976
# Iteration 167: Cost = 2.9731
# Iteration 168: Cost = 2.9488
# Iteration 169: Cost = 2.9247
# Iteration 170: Cost = 2.9008
# Iteration 171: Cost = 2.8772
# Iteration 172: Cost = 2.8538
# Iteration 173: Cost = 2.8306
# Iteration 174: Cost = 2.8076
# Iteration 175: Cost = 2.7848
# Iteration 176: Cost = 2.7622
# Iteration 177: Cost = 2.7399
# Iteration 178: Cost = 2.7177
# Iteration 179: Cost = 2.6958
# Iteration 180: Cost = 2.6740
# Iteration 181: Cost = 2.6524
# Iteration 182: Cost = 2.6311
# Iteration 183: Cost = 2.6099
# Iteration 184: Cost = 2.5889
# Iteration 185: Cost = 2.5681
# Iteration 186: Cost = 2.5475
# Iteration 187: Cost = 2.5271
# Iteration 188: Cost = 2.5069
# Iteration 189: Cost = 2.4869
# Iteration 190: Cost = 2.4670
# Iteration 191: Cost = 2.4473
# Iteration 192: Cost = 2.4278
# Iteration 193: Cost = 2.4085
# Iteration 194: Cost = 2.3894
# Iteration 195: Cost = 2.3704
# Iteration 196: Cost = 2.3516
# Iteration 197: Cost = 2.3330
# Iteration 198: Cost = 2.3145
# Iteration 199: Cost = 2.2963
# Iteration 200: Cost = 2.2781
# Iteration 201: Cost = 2.2602
# Iteration 202: Cost = 2.2424
# Iteration 203: Cost = 2.2248
# Iteration 204: Cost = 2.2073
# Iteration 205: Cost = 2.1900
# Iteration 206: Cost = 2.1728
# Iteration 207: Cost = 2.1558
# Iteration 208: Cost = 2.1390
# Iteration 209: Cost = 2.1223
# Iteration 210: Cost = 2.1058
# Iteration 211: Cost = 2.0894
# Iteration 212: Cost = 2.0732
# Iteration 213: Cost = 2.0571
# Iteration 214: Cost = 2.0411
# Iteration 215: Cost = 2.0253
# Iteration 216: Cost = 2.0097
# Iteration 217: Cost = 1.9942
# Iteration 218: Cost = 1.9788
# Iteration 219: Cost = 1.9636
# Iteration 220: Cost = 1.9485
# Iteration 221: Cost = 1.9335
# Iteration 222: Cost = 1.9187
# Iteration 223: Cost = 1.9040
# Iteration 224: Cost = 1.8895
# Iteration 225: Cost = 1.8751
# Iteration 226: Cost = 1.8608
# Iteration 227: Cost = 1.8466
# Iteration 228: Cost = 1.8326
# Iteration 229: Cost = 1.8187
# Iteration 230: Cost = 1.8049
# Iteration 231: Cost = 1.7913
# Iteration 232: Cost = 1.7778
# Iteration 233: Cost = 1.7644
# Iteration 234: Cost = 1.7511
# Iteration 235: Cost = 1.7379
# Iteration 236: Cost = 1.7249
# Iteration 237: Cost = 1.7120
# Iteration 238: Cost = 1.6992
# Iteration 239: Cost = 1.6865
# Iteration 240: Cost = 1.6739
# Iteration 241: Cost = 1.6615
# Iteration 242: Cost = 1.6491
# Iteration 243: Cost = 1.6369
# Iteration 244: Cost = 1.6248
# Iteration 245: Cost = 1.6128
# Iteration 246: Cost = 1.6008
# Iteration 247: Cost = 1.5891
# Iteration 248: Cost = 1.5774
# Iteration 249: Cost = 1.5658
# Iteration 250: Cost = 1.5543
# Iteration 251: Cost = 1.5429
# Iteration 252: Cost = 1.5317
# Iteration 253: Cost = 1.5205
# Iteration 254: Cost = 1.5094
# Iteration 255: Cost = 1.4985
# Iteration 256: Cost = 1.4876
# Iteration 257: Cost = 1.4768
# Iteration 258: Cost = 1.4662
# Iteration 259: Cost = 1.4556
# Iteration 260: Cost = 1.4451
# Iteration 261: Cost = 1.4347
# Iteration 262: Cost = 1.4245
# Iteration 263: Cost = 1.4143
# Iteration 264: Cost = 1.4042
# Iteration 265: Cost = 1.3941
# Iteration 266: Cost = 1.3842
# Iteration 267: Cost = 1.3744
# Iteration 268: Cost = 1.3647
# Iteration 269: Cost = 1.3550
# Iteration 270: Cost = 1.3454
# Iteration 271: Cost = 1.3360
# Iteration 272: Cost = 1.3266
# Iteration 273: Cost = 1.3173
# Iteration 274: Cost = 1.3080
# Iteration 275: Cost = 1.2989
# Iteration 276: Cost = 1.2898
# Iteration 277: Cost = 1.2809
# Iteration 278: Cost = 1.2720
# Iteration 279: Cost = 1.2631
# Iteration 280: Cost = 1.2544
# Iteration 281: Cost = 1.2457
# Iteration 282: Cost = 1.2372
# Iteration 283: Cost = 1.2287
# Iteration 284: Cost = 1.2202
# Iteration 285: Cost = 1.2119
# Iteration 286: Cost = 1.2036
# Iteration 287: Cost = 1.1954
# Iteration 288: Cost = 1.1873
# Iteration 289: Cost = 1.1793
# Iteration 290: Cost = 1.1713
# Iteration 291: Cost = 1.1634
# Iteration 292: Cost = 1.1555
# Iteration 293: Cost = 1.1478
# Iteration 294: Cost = 1.1401
# Iteration 295: Cost = 1.1325
# Iteration 296: Cost = 1.1249
# Iteration 297: Cost = 1.1174
# Iteration 298: Cost = 1.1100
# Iteration 299: Cost = 1.1026
# Iteration 300: Cost = 1.0953
# Iteration 301: Cost = 1.0881
# Iteration 302: Cost = 1.0810
# Iteration 303: Cost = 1.0739
# Iteration 304: Cost = 1.0669
# Iteration 305: Cost = 1.0599
# Iteration 306: Cost = 1.0530
# Iteration 307: Cost = 1.0461
# Iteration 308: Cost = 1.0394
# Iteration 309: Cost = 1.0326
# Iteration 310: Cost = 1.0260
# Iteration 311: Cost = 1.0194
# Iteration 312: Cost = 1.0129
# Iteration 313: Cost = 1.0064
# Iteration 314: Cost = 1.0000
# Iteration 315: Cost = 0.9936
# Iteration 316: Cost = 0.9873
# Iteration 317: Cost = 0.9810
# Iteration 318: Cost = 0.9748
# Iteration 319: Cost = 0.9687
# Iteration 320: Cost = 0.9626
# Iteration 321: Cost = 0.9566
# Iteration 322: Cost = 0.9506
# Iteration 323: Cost = 0.9447
# Iteration 324: Cost = 0.9388
# Iteration 325: Cost = 0.9330
# Iteration 326: Cost = 0.9273
# Iteration 327: Cost = 0.9215
# Iteration 328: Cost = 0.9159
# Iteration 329: Cost = 0.9103
# Iteration 330: Cost = 0.9047
# Iteration 331: Cost = 0.8992
# Iteration 332: Cost = 0.8938
# Iteration 333: Cost = 0.8883
# Iteration 334: Cost = 0.8830
# Iteration 335: Cost = 0.8777
# Iteration 336: Cost = 0.8724
# Iteration 337: Cost = 0.8672
# Iteration 338: Cost = 0.8620
# Iteration 339: Cost = 0.8569
# Iteration 340: Cost = 0.8518
# Iteration 341: Cost = 0.8468
# Iteration 342: Cost = 0.8418
# Iteration 343: Cost = 0.8368
# Iteration 344: Cost = 0.8319
# Iteration 345: Cost = 0.8271
# Iteration 346: Cost = 0.8223
# Iteration 347: Cost = 0.8175
# Iteration 348: Cost = 0.8128
# Iteration 349: Cost = 0.8081
# Iteration 350: Cost = 0.8034
# Iteration 351: Cost = 0.7988
# Iteration 352: Cost = 0.7943
# Iteration 353: Cost = 0.7897
# Iteration 354: Cost = 0.7853
# Iteration 355: Cost = 0.7808
# Iteration 356: Cost = 0.7764
# Iteration 357: Cost = 0.7720
# Iteration 358: Cost = 0.7677
# Iteration 359: Cost = 0.7634
# Iteration 360: Cost = 0.7592
# Iteration 361: Cost = 0.7550
# Iteration 362: Cost = 0.7508
# Iteration 363: Cost = 0.7467
# Iteration 364: Cost = 0.7426
# Iteration 365: Cost = 0.7385
# Iteration 366: Cost = 0.7345
# Iteration 367: Cost = 0.7305
# Iteration 368: Cost = 0.7265
# Iteration 369: Cost = 0.7226
# Iteration 370: Cost = 0.7187
# Iteration 371: Cost = 0.7149
# Iteration 372: Cost = 0.7111
# Iteration 373: Cost = 0.7073
# Iteration 374: Cost = 0.7035
# Iteration 375: Cost = 0.6998
# Iteration 376: Cost = 0.6961
# Iteration 377: Cost = 0.6925
# Iteration 378: Cost = 0.6889
# Iteration 379: Cost = 0.6853
# Iteration 380: Cost = 0.6817
# Iteration 381: Cost = 0.6782
# Iteration 382: Cost = 0.6747
# Iteration 383: Cost = 0.6712
# Iteration 384: Cost = 0.6678
# Iteration 385: Cost = 0.6644
# Iteration 386: Cost = 0.6610
# Iteration 387: Cost = 0.6577
# Iteration 388: Cost = 0.6544
# Iteration 389: Cost = 0.6511
# Iteration 390: Cost = 0.6479
# Iteration 391: Cost = 0.6446
# Iteration 392: Cost = 0.6414
# Iteration 393: Cost = 0.6383
# Iteration 394: Cost = 0.6351
# Iteration 395: Cost = 0.6320
# Iteration 396: Cost = 0.6289
# Iteration 397: Cost = 0.6259
# Iteration 398: Cost = 0.6228
# Iteration 399: Cost = 0.6198
# Iteration 400: Cost = 0.6169
# Iteration 401: Cost = 0.6139
# Iteration 402: Cost = 0.6110
# Iteration 403: Cost = 0.6081
# Iteration 404: Cost = 0.6052
# Iteration 405: Cost = 0.6024
# Iteration 406: Cost = 0.5995
# Iteration 407: Cost = 0.5967
# Iteration 408: Cost = 0.5940
# Iteration 409: Cost = 0.5912
# Iteration 410: Cost = 0.5885
# Iteration 411: Cost = 0.5858
# Iteration 412: Cost = 0.5831
# Iteration 413: Cost = 0.5804
# Iteration 414: Cost = 0.5778
# Iteration 415: Cost = 0.5752
# Iteration 416: Cost = 0.5726
# Iteration 417: Cost = 0.5700
# Iteration 418: Cost = 0.5675
# Iteration 419: Cost = 0.5650
# Iteration 420: Cost = 0.5625
# Iteration 421: Cost = 0.5600
# Iteration 422: Cost = 0.5576
# Iteration 423: Cost = 0.5551
# Iteration 424: Cost = 0.5527
# Iteration 425: Cost = 0.5503
# Iteration 426: Cost = 0.5479
# Iteration 427: Cost = 0.5456
# Iteration 428: Cost = 0.5433
# Iteration 429: Cost = 0.5410
# Iteration 430: Cost = 0.5387
# Iteration 431: Cost = 0.5364
# Iteration 432: Cost = 0.5341
# Iteration 433: Cost = 0.5319
# Iteration 434: Cost = 0.5297
# Iteration 435: Cost = 0.5275
# Iteration 436: Cost = 0.5253
# Iteration 437: Cost = 0.5232
# Iteration 438: Cost = 0.5210
# Iteration 439: Cost = 0.5189
# Iteration 440: Cost = 0.5168
# Iteration 441: Cost = 0.5147
# Iteration 442: Cost = 0.5127
# Iteration 443: Cost = 0.5106
# Iteration 444: Cost = 0.5086
# Iteration 445: Cost = 0.5066
# Iteration 446: Cost = 0.5046
# Iteration 447: Cost = 0.5026
# Iteration 448: Cost = 0.5007
# Iteration 449: Cost = 0.4987
# Iteration 450: Cost = 0.4968
# Iteration 451: Cost = 0.4949
# Iteration 452: Cost = 0.4930
# Iteration 453: Cost = 0.4911
# Iteration 454: Cost = 0.4893
# Iteration 455: Cost = 0.4874
# Iteration 456: Cost = 0.4856
# Iteration 457: Cost = 0.4838
# Iteration 458: Cost = 0.4820
# Iteration 459: Cost = 0.4802
# Iteration 460: Cost = 0.4784
# Iteration 461: Cost = 0.4767
# Iteration 462: Cost = 0.4749
# Iteration 463: Cost = 0.4732
# Iteration 464: Cost = 0.4715
# Iteration 465: Cost = 0.4698
# Iteration 466: Cost = 0.4681
# Iteration 467: Cost = 0.4665
# Iteration 468: Cost = 0.4648
# Iteration 469: Cost = 0.4632
# Iteration 470: Cost = 0.4616
# Iteration 471: Cost = 0.4599
# Iteration 472: Cost = 0.4584
# Iteration 473: Cost = 0.4568
# Iteration 474: Cost = 0.4552
# Iteration 475: Cost = 0.4536
# Iteration 476: Cost = 0.4521
# Iteration 477: Cost = 0.4506
# Iteration 478: Cost = 0.4491
# Iteration 479: Cost = 0.4476
# Iteration 480: Cost = 0.4461
# Iteration 481: Cost = 0.4446
# Iteration 482: Cost = 0.4431
# Iteration 483: Cost = 0.4417
# Iteration 484: Cost = 0.4402
# Iteration 485: Cost = 0.4388
# Iteration 486: Cost = 0.4374
# Iteration 487: Cost = 0.4360
# Iteration 488: Cost = 0.4346
# Iteration 489: Cost = 0.4332
# Iteration 490: Cost = 0.4318
# Iteration 491: Cost = 0.4305
# Iteration 492: Cost = 0.4291
# Iteration 493: Cost = 0.4278
# Iteration 494: Cost = 0.4265
# Iteration 495: Cost = 0.4251
# Iteration 496: Cost = 0.4238
# Iteration 497: Cost = 0.4225
# Iteration 498: Cost = 0.4213
# Iteration 499: Cost = 0.4200

# %% [markdown]
# To have a better understanding of how gradient descent actually works, we build a function that virtualizes the training dynamics for different iterations and learning rates combination.

# %%
def plot_gradient_descent(
    num_iterations, learning_rate, X_b, y, data_axis, cost_axis=None
):
    """
    Visualize gradient descent optimization for linear regression.

    Parameters:
    - num_iterations (int): Number of iterations for gradient descent.
    - learning_rate (float): Learning rate for gradient descent.
    - X_b (numpy.ndarray): Feature matrix of shape (num_samples, num_features).
    - y (numpy.ndarray): Target values of shape (num_samples,).
    - data_axis (matplotlib Axis): Axis to visualize the data points and regression lines.
    - cost_axis (matplotlib Axis): Optional axis to visualize the cost history vs. iterations.

    """
    # Plot the data points as blue dots
    data_axis.plot(
        # Assuming the second column is for the intercept term, select the
        # first column.
        X_b[:, 0], y, "b."
    )
    # Initialize random theta values from a standard normal distribution
    theta = np.random.randn(2, 1)

    # Initial transparency value for plotting regression lines
    transparency = 0.05

    # Initialize an array to store cost history during iterations
    cost_history = np.zeros(num_iterations)

    # Loop through each iteration
    for i in range(num_iterations):
        # Compute predictions using the current theta values
        predictions_prev = X_b.dot(theta)

        # Perform one iteration of gradient descent to update theta values
        theta, current_cost = gradient_descent(X_b, y, theta, learning_rate, 1)

        # Compute predictions using the updated theta values
        predictions = X_b.dot(theta)

        # Store the cost value after the current iteration
        cost_history[i] = current_cost[0]

        # Plot the regression line with adjusted transparency
        if i % 25 == 0:
            data_axis.plot(
                X_b[:, 0], predictions, "r-", alpha=transparency
            )  # Assuming the first column is for the intercept term
            if transparency < 0.8:
                transparency += 0.15

    # If provided, plot cost history vs. iterations
    if cost_axis is not None:
        cost_axis.plot(range(num_iterations), cost_history, "b.")


# Create a figure with subplots for visualization
fig = plt.figure(figsize=(20, 20))
fig.subplots_adjust(hspace=0.2, wspace=0.2)

# List of iteration and learning rate pairs to iterate through
number_of_iteration_learning_rate_pairs = [(1000, 0.001), (500, 0.01), (100, 0.02)]

# Initialize the subplot count for positioning
subplot_count = 0

# Loop through each iteration and learning rate pair
for number_of_iterations, lr in number_of_iteration_learning_rate_pairs:
    # Increment the subplot count and create data and cost axes
    subplot_count += 1
    data_axis = fig.add_subplot(4, 2, subplot_count)
    subplot_count += 1
    cost_axis = fig.add_subplot(4, 2, subplot_count)

    # Set titles for the data and cost axes
    data_axis.set_title("Learning Rate: {}".format(lr))
    cost_axis.set_title("Iterations: {}".format(number_of_iterations))

    # Call the function to visualize gradient descent
    plot_gradient_descent(
        number_of_iterations, lr, X_b, y, data_axis, cost_axis
    )

# %% [markdown]
# ### **TODO 4:**
# In the next cell, write a function to implement Stochastic Gradient Descent (SGD).
#
# 1.  Loop `iterations` times.
# 2.  In each iteration:
#     *   Randomly select a single sample index.
#     *   Extract `sample_X` and `sample_y` for that index.
#     *   Calculate residuals and gradient *for that sample only*.
#     *   Update `theta` using the gradient.
#     *   Calculate cost (MSE) for that sample and track it.

# %%
def stochastic_gradient_descent(X, y, theta, learning_rate=0.01, iterations=10):
    """
    Perform stochastic gradient descent.
    """
    num_samples = len(y)
    cost_history = []

    for iteration in range(iterations):
        # 1. Select a random sample index
        random_index = np.random.randint(0, num_samples)

        # 2. Get the sample X and y, ensuring they remain 2D arrays (1, num_features) and (1, 1)
        sample_X = X[random_index,:].reshape(1,-1)
        sample_y = y[random_index]


        # 3. Calculate residuals
        _,residuals = calculate_prediction_residuals(theta, sample_X, sample_y)

        # 4. Calculate gradient
        gradient = calculate_gradient(sample_X, residuals)


        # 5. Update theta
        theta = theta - learning_rate * gradient

        # 6. Calculate cost and append to history
        # The cost should ideally be calculated over the full dataset for a meaningful trend
        # but for SGD, it's common to track the cost of the current sample or an average.
        # For simplicity and to match the previous calculation, let's use the current sample's cost.
        cost = calculate_cost(theta, sample_X , sample_y)
        cost_history.append(cost)
        pass

    return theta, cost_history

# %% [markdown]
# Run your SGD implementation and plot the cost vs iteration.

# %%
# Skeleton for TODO 4 (continued)
theta = theta_guess.copy()
X_b = np.c_[X, np.ones((len(X), 1))]

# 1. Run Stochastic Gradient Descent
np.random.seed(80)
theta, cost_history = stochastic_gradient_descent(X_b, y, theta)
iterations =10

# 2. Plot cost history
plt.figure(figsize=(10, 6))
plt.plot(range(iterations), cost_history)
plt.xlabel('Iteration')
plt.ylabel('Cost (MSE)')
plt.title('Stochastic Gradient Descent - Cost History')
plt.grid(True)
plt.show()
# Out:
# 10

# %% [markdown]
# ### **TODO 5:**
# In the next cell, implement the SGD with Momentum.
#
# 1.  Initialize `velocity` as zeros with same shape as `theta`.
# 2.   Loop `iterations` times.
# 3.  Inside loop (similar to SGD):
#     *   Random sample.
#     *   Calculate gradient.
#     *   Update `velocity`: $v_{new} = \text{momentum} \times v_{old} + (1 - \text{momentum}) \times \text{gradient}$.
#     *   Update `theta`: $\theta = \theta - \alpha \times v_{new}$.
#     *   Track cost.

# %%
# Skeleton for TODO 5
def stochastic_gradient_descent_with_momentum(X, y, theta, learning_rate=0.01, momentum=0.9, iterations=10):
    """
    Perform SGD with Momentum.
    """
    num_samples = len(y)
    cost_history = []
    velocity = np.zeros_like(theta)

    for iteration in range(iterations):
        # 1. Select a random sample
        random_index = np.random.randint(0, num_samples)
        sample_X = X[random_index,:].reshape(1,-1)
        sample_y = y[random_index]


        # 2. Calculate gradient
        _, residuals = calculate_prediction_residuals(theta, sample_X, sample_y)
        gradient = calculate_gradient(sample_X, residuals)

        # 3. Update velocity
        velocity = momentum * velocity + (1 - momentum) * gradient

        # 4. Update theta using velocity
        theta = theta - learning_rate * velocity

        # 5. Calculate cost
        cost = calculate_cost(theta, sample_X, sample_y)
        cost_history.append(cost)
        pass

    return theta, cost_history

# %% [markdown]
# Call your implementation of SGD with Momentum and plot the Cost vs iteration.

# %%
# Skeleton for TODO 5 (continued)
theta = theta_guess.copy()
X_b = np.c_[X, np.ones((len(X), 1))]
momentum = 0.9

# 1. Run SGD with Momentum

theta, cost_history = stochastic_gradient_descent_with_momentum(X_b, y, theta)



# 2. Plot cost history
plt.figure(figsize=(10, 6))
plt.plot(range(iterations), cost_history)
plt.xlabel('Iteration')
plt.ylabel('Cost (MSE)')
plt.title('Stochastic Gradient Descent with momentum - Cost History')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Mini Batch Stochastic Gradient Descent
#
# Mini-batch stochastic gradient descent (MBSGD) is a variation of stochastic gradient descent (SGD) where updates are made using small batches of data instead of single examples.
#
# ### **TODO 6:**
# Implement `minibatch_gradient_descent` in the next cell.
#
# 1.  Loop `iterations` times.
# 2.  In each iteration:
#     *   Select random indices of size `batch_size`.
#     *   Construct `X_batch` and `y_batch`.
#     *   Calculate residuals and gradient using the batch.
#     *   Update `theta` (using learning rate and gradient).
#     *   Calculate cost for the batch (or full dataset, but usually batch cost) and track it.

# %%
# Skeleton for TODO 6
def minibatch_gradient_descent(X, y, theta, learning_rate=0.01, iterations=10, batch_size=20):
    """
    Perform Mini-Batch Gradient Descent.
    """
    num_samples = len(y)
    cost_history = []

    for iteration in range(iterations):
        # 1. Select random indices for the batch
        # ... your code here ...

        # 2. Get batch X and y
        # ... your code here ...

        # 3. Calculate gradient on the batch
        # ... your code here ...

        # 4. Update theta
        # ... your code here ...

        # 5. Calculate cost
        # ... your code here ...
        pass

    return theta, cost_history

# %% [markdown]
# Run your implementation and plot the cost vs iteration.

# %%
# Skeleton for TODO 6 (continued)
theta = theta_guess.copy()
X_b = np.c_[X, np.ones((len(X), 1))]
batch_size = 10

# 1. Run Mini-batch Gradient Descent
# theta, cost_history = ...

# 2. Plot cost history
# ... your code here ...

# %% [markdown]
# ### **TODO 7:**
# Answer the following questions in the next cell.
#
# For these algorithms: GD, SGD, SGD with momentum, MBGD, answer these questions:
#
# 1. Assuming the learning rate is the same for all algorithms, what is the worst case runtime complexity of each algorithm. Your answer should be a function of `num_samples`, `num_of_iteration`, and `batch_size`.
# 2. How would you compare the computation efficiency of each algorithm?
# 3. How would momentum help with the convergence?
# 4. How would different learning rate values affect gradient descent algorithms?
# 5. Does gradient descent always converge to optimum?
# 6. What are overfitting and underfitting in machine learning? How to reduce overfitting and underfitting? Check this [reference](https://www.geeksforgeeks.org/underfitting-and-overfitting-in-machine-learning/).

# %% [markdown]
# Your answer:

# %% [markdown]
# ### **TODO 8:**
# In the next cell write a function to perform linear regression using PyTorch. Check this [reference](https://www.geeksforgeeks.org/linear-regression-using-pytorch/).
#
# 1.  Define a `LinearRegressionModel` class inheriting from `nn.Module`.
#     *   In `__init__`, define a `nn.Linear` layer.
#     *   In `forward`, pass input through the linear layer.
# 2.  Instantiate the model.
# 3.  Define the Loss function (`nn.MSELoss`) and Optimizer (`SGD` or `Adam`).
# 4.  Implement the training loop:
#     *   Set model to train mode.
#     *   Zero gradients.
#     *   Forward pass.
#     *   Compute loss.
#     *   Backward pass.
#     *   Optimizer step.
# 5.  Return the trained model.

# %%
# Skeleton for TODO 8
import torch
import torch.nn as nn
import torch.optim as optim

def train_linear_regression(X, y, optimizer_type='SGD', learning_rate=0.01, num_epochs=1000):
    """
    Train a linear regression model using PyTorch.
    """
    # 1. Define LinearRegressionModel class
    class LinearRegressionModel(nn.Module):
        def __init__(self):
            super(LinearRegressionModel, self).__init__()
            # ... your code here ...
            pass

        def forward(self, x):
            # ... your code here ...
            pass

    # 2. Instantiate model
    model = LinearRegressionModel()

    # 3. Define Loss Function (MSE)
    # ... your code here ...

    # 4. Define Optimizer
    if optimizer_type == 'SGD':
        # ... your code here ...
        pass
    elif optimizer_type == 'Adam':
        # ... your code here ...
        pass

    # 5. Training Loop
    for epoch in range(num_epochs):
        # ... your code here ...
        pass

    return model

# %% [markdown]
# Run your implementation `train_linear_regression`.
# Plot the trained line on top of the data plot.
# Print your model parameters $\theta$.

# %%
# Skeleton for TODO 8 (continued)
# 1. Convert data to tensors
# X_tensor = ...
# y_tensor = ...

# 2. Train model using train_linear_regression
# trained_model = ...

# 3. Print model parameters (weight and bias)
# ...

# 4. Plot Data Points vs Learned Line
# ...
